# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
import h5py
from matplotlib import colors
import matplotlib.pyplot as plt
import multiprocessing
from neural_analysis.matIO import loadmat
import numpy as np
import os
import pandas as pd
import ssm
from ssm.util import find_permutation
import sys
import time
from tqdm.auto import tqdm

sys.path.append('../..')
from multi_process import slds_eigs_worker
from nld_utils import simulate_lorenz
from up_down import get_up_down
from utils import get_binary_stimuli, get_sample_interval, load, save

# %% [markdown]
# ## Load Neural Data

# %%
# filename = '../../__data__/Mary-Anesthesia-20160809-01.mat'
filename = r'/home/adameisen/millerdata/common/datasets/anesthesia/mat/propofolPuffTone/Mary-Anesthesia-20160809-01.mat'
# filename = r'/home/adameisen/millerdata/common/datasets/anesthesia/mat/propofolWakeup/Mary-Anesthesia-20170203-02.mat'
print("Loading data ...")
start = time.process_time()
# electrode_info, lfp, lfp_schema, session_info, spike_times, unit_info = loadmat(filename, variables=['electrodeInfo', 'lfp', 'lfpSchema', 'sessionInfo', 'spikeTimes', 'unitInfo'], verbose=False)
electrode_info, lfp_schema, session_info, unit_info = loadmat(filename, variables=['electrodeInfo', 'lfpSchema', 'sessionInfo', 'unitInfo'], verbose=False)
dt = lfp_schema['smpInterval'][0]

f = h5py.File(filename, 'r')
airPuff_binary, audio_binary = get_binary_stimuli(f)

print(f"Data loaded (took {time.process_time() - start:.2f} seconds)")
# Out:
# Loading data ...
# Data loaded (took 2.25 seconds)

# %%
# mat_dir = r'/home/adameisen/millerdata/common/datasets/anesthesia/mat/propofolPuffTone'
# for file in os.listdir(mat_dir):
#     filename = os.path.join(mat_dir, file)
#     electrode_info, lfp_schema, session_info, unit_info = loadmat(filename, variables=['electrodeInfo', 'lfpSchema', 'sessionInfo', 'unitInfo'], verbose=False)
#     print(session_info['drug'])

# %%
loadmat(r'/home/adameisen/millerdata/common/datasets/anesthesia/mat/anesthesia_databases.mat')
# Out:
# fileInfo : dict with keys[session,file,dataSource,recordSys,recordSysModel,version,dateTime,duration,clockFreq,waveSmpFreq,numWaveSmps,numWavePreSmps,waveBitRes,analogBitRes,Properties,]
#
# sessionInfo : dict with keys[session,subject,tasks,areas,arrays,NSPs,hasDrug,drug,drugDose,drugDuration,drugStart,drugEnd,eyesClose,eyesOpen,drugTask,hasWakeUpTest,numTrials,numCorrect,pctCorrect,pctBadTrials,Properties,]
#
# spikeChnlInfo : dict with keys[chnlID,electrode,channel,chnlLabel,numUnits,numUnitSpikes,numUnsortedSpikes,smpRate,digitalRange,d2aFactor,analogRange,analogUnits,filterCutoff,session,file,Properties,]
#
# analogChnlInfo : dict with keys[chnlID,electrode,channel,chnlLabel,numSamples,smpRate,digitalRange,d2aFactor,analogRange,analogUnits,filterCutoff,isLFP,isAIN,session,file,Properties,]
#
# electrodeInfo : dict with keys[electrode,chnlID,channel,session,file,hasLFP,numUnits,hemisphere,area,array,NSP,gridLoc,Properties,]
#
# unitInfo : dict with keys[unitID,electrode,channel,unit,numSpikes,chnlID,session,file,hemisphere,area,array,NSP,gridLoc,Properties,]
# ({'session': array(['MrJones-Anesthesia-20160105-01', 'MrJones-Anesthesia-20160107-01',
#           5667.64866667,  6054.5606    ,  6750.63223333,  6205.19363333,
#           6914.9476    ,  6642.92746667,  6504.26883333,  6200.41013333,
#           6476.71723333, 14477.4197    , 15542.39863333, 14280.7751    ,
#          13525.4448    , 14183.17103333, 16135.34186667, 15520.1675    ,
#          17351.56556667, 15590.24776667,  9371.00056667,  8632.504     ,
#           7481.085     ,  9042.29106667,  7890.52126667,  8417.88163333,
#           7989.67193333,  9603.7228    ,  8373.27326667,  9063.56683333,
#          10952.182     , 10381.9279    , 11398.36463333, 11966.67496667,
#           7512.1631    ,  8527.27726667,  9389.772     ,  7600.9256    ,
#           8009.7496    ,  7578.21156667, 11356.67103333,  9914.81236667,
#           2347.7947    ,  2569.37776667,  2321.64636667,  2030.0217    ]),
#   'clockFreq': array([30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000,
#          30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000,
#          30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000,
#          30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000,
#          30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000,
#          30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000,
#          30000, 30000], dtype=uint16),
#   'waveSmpFreq': array([30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000,
#          30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000,
#          30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000,
#          30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000,
#          30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000,
#          30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000, 30000,
#          30000, 30000], dtype=uint16),
#   'numWaveSmps': array([48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48,
#          48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48,
#          48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48,
#          48, 48, 48, 48, 48], dtype=uint8),
#   'numWavePreSmps': array([10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10,
#          10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10,
#          10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10,
#          10, 10, 10, 10, 10], dtype=uint8),
#   'waveBitRes': array([16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16,
#          16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16,
#          16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16,
#          16, 16, 16, 16, 16], dtype=uint8),
#   'analogBitRes': array([16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16,
#          16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16,
#          16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16,
#          16, 16, 16, 16, 16], dtype=uint8),
#   'Properties': {'Description': array('Datafile metadata for session MrJones-Anesthesia-20160105-01',
#          dtype='<U60'),
#    'UserData': array([], shape=(0, 0), dtype=uint8),
#    'DimensionNames': array([array(['Session'], dtype='<U7'), array(['Variable'], dtype='<U8')],
#          dtype=object),
#    'VariableNames': array([array(['session'], dtype='<U7'), array(['file'], dtype='<U4'),
#           array(['dataSource'], dtype='<U10'),
#           array(['recordSys'], dtype='<U9'),
#           array(['recordSysModel'], dtype='<U14'),
#           array(['version'], dtype='<U7'), array(['dateTime'], dtype='<U8'),
#           array(['duration'], dtype='<U8'),
#           array(['clockFreq'], dtype='<U9'),
#           array(['waveSmpFreq'], dtype='<U11'),
#           array(['numWaveSmps'], dtype='<U11'),
#           array(['numWavePreSmps'], dtype='<U14'),
#           array(['waveBitRes'], dtype='<U10'),
#           array(['analogBitRes'], dtype='<U12')], dtype=object),
#    'VariableDescriptions': array([array(['SessionID string'], dtype='<U16'),
#           array(['Filename info loaded from'], dtype='<U25'),
#           array(['Data source type'], dtype='<U16'),
#           array(['Recording system used to collect data'], dtype='<U37'),
#           array(['Specific model of recording system used'], dtype='<U39'),
#           array(['Version of datafile format'], dtype='<U26'),
#           array(['Date and time of data collection'], dtype='<U32'),
#           array(['Duration of datafile (in s)'], dtype='<U27'),
#           array(['Frequency of system clock for timestamps (Hz)'], dtype='<U45'),
#           array(['Sampling frequency for spike waveforms (Hz)'], dtype='<U43'),
#           array(['Number of samples in each spike waveform'], dtype='<U40'),
#           array(['Number of spike waveform samples before threshold crossing'],
#                 dtype='<U58')                                                  ,
#           array(['Resolution of the spike A/D converter'], dtype='<U37'),
#           array(['Resolution of the analog A/D converter'], dtype='<U38')],
#          dtype=object),
#    'VariableUnits': array([array([], dtype='<U1'), array([], dtype='<U1'),
#           array([], dtype='<U1'), array([], dtype='<U1'),
#           array([], dtype='<U1'), array([], dtype='<U1'),
#           array([], dtype='<U1'), array(['s'], dtype='<U1'),
#           array(['Hz'], dtype='<U2'), array(['Hz'], dtype='<U2'),
#           array([], dtype='<U1'), array([], dtype='<U1'),
#           
#          'Mary-Anesthesia-20160627-01', 'Mary-Anesthesia-20160711-01',
#          'Mary-Anesthesia-20160715-01', 'Mary-Anesthesia-20160718-01',
#          'Mary-Anesthesia-20160720-01', 'Mary-Anesthesia-20160722-01',
#          'Mary-Anesthesia-20160906-01', 'Mary-Anesthesia-20160920-01',
#          'MrJones-Anesthesia-20161009-02', 'MrJones-Anesthesia-20161009-03',
#          'MrJones-Anesthesia-20161010-05', 'MrJones-Anesthesia-20161010-06'],
#         dtype=object),
#   'subject': array(['MrJones', 'MrJones', 'MrJones', 'MrJones', 'MrJones', 'MrJones',
#          'MrJones', 'MrJones', 'MrJones', 'MrJones', 'MrJones', 'Mary',
#          'Mary', 'Mary', 'Mary', 'Mary', 'Mary', 'Mary', 'Mary', 'Mary',
#          'Mary', 'MrJones', 'MrJones', 'MrJones', 'MrJones', 'MrJones',
#          'MrJones', 'MrJones', 'MrJones', 'MrJones', 'MrJones', 'MrJones',
#          'Mary', 'Mary', 'Mary', 'Mary', 'Mary', 'Mary', 'Mary', 'Mary',
#          'Mary', 'Mary', 'MrJones', 'MrJones', 'Mary', 'Mary', 'Mary',
#          'Mary', 'Mary', 'Mary', 'Mary', 'Mary', 'MrJones', 'MrJones',
#          'MrJones', 'MrJones'], dtype=object),
#   'tasks': array([array([array(['delSac'], dtype='<U6'), array(['puffTone'], dtype='<U8'),
#                 array(['delSac'], dtype='<U6')], dtype=object)                   ,
#          array([array(['delSac'], dtype='<U6'), array(['puffTone'], dtype='<U8'),
#                 array(['delSac'], dtype='<U6')], dtype=object)                   ,
#          array([array(['delSac'], dtype='<U6'), array(['puffTone'], dtype='<U8'),
#                 array(['delSac'], dtype='<U6')], dtype=object)                   ,
#          array([array(['delSac'], dtype='<U6'), array(['puffTone'], dtype='<U8'),
#                 array(['delSac'], dtype='<U6')], dtype=object)                   ,
#          array([array(['delSac'], dtype='<U6'), array(['puffTone'], dtype='<U8'),
#                 array(['delSac'], dtype='<U6')], dtype=object)                   ,
#          array([array(['delSac'], dtype='<U6'), array(['puffTone'], dtype='<U8'),
#                 array(['delSac'], dtype='<U6')], dtype=object)                   ,
#          array([array(['delSac'], dtype='<U6'), array(['puffTone'], dtype='<U8'),
#                 array(['delSac'], dtype='<U6')], dtype=object)                   ,
#          array([array(['delSac'], dtype='<U6'), array(['puffTone'], dtype='<U8'),
#                 array(['delSac'], dtype='<U6')], dtype=object)                   ,
#          array([array(['delSac'], dtype='<U6'), array(['puffTone'], dtype='<U8'),
#                 array(['delSac'], dtype='<U6')], dtype=object)                   ,
#          array([array(['delSac'], dtype='<U6'), array(['puffTone'], dtype='<U8'),
#                 array(['delSac'], dtype='<U6')], dtype=object)                   ,
#          array([array(['delSac'], dtype='<U6'), array(['puffTone'], dtype='<U8'),
#                 array(['delSac'], dtype='<U6')], dtype=object)                   ,
#          array('puffTone', dtype='<U8'), array('puffTone', dtype='<U8'),
#          array('puffTone', dtype='<U8'), array('puffTone', dtype='<U8'),
#          array('puffTone', dtype='<U8'), array('puffTone', dtype='<U8'),
#          array('puffTone', dtype='<U8'), array('puffTone', dtype='<U8'),
#          array('puffTone', dtype='<U8'), array('puffTone', dtype='<U8'),
#          array([array(['BRstimTest'], dtype='<U10'),
#                 array(['delSac'], dtype='<U6'), array(['puffTone'], dtype='<U8'),
#                 array(['DBS'], dtype='<U3'), array(['BRstimTest'], dtype='<U10')],
#                dtype=object)                                                      ,
#          array([array(['BRstimTest'], dtype='<U10'),
#                 array(['delSac'], dtype='<U6'), array(['puffTone'], dtype='<U8'),
#                 array(['DBS'], dtype='<U3'), array(['BRstimTest'], dtype='<U10')],
#                dtype=object)                                                      ,
#          array([array(['BRstimTest'], dtype='<U10'),
#                 array(['stimPulses'], dtype='<U10'),
#                 array(['delSac'], dtype='<U6'), array(['puffTone'], dtype='<U8'),
#                 array(['DBS'], dtype='<U3'), array(['stimPulses'], dtype='<U10'),
#                 array(['BRstimTest'], dtype='<U10')], dtype=object)              ,
#          array([array(['delSac'], dtype='<U6'),
#                 array(['BRstimTest'], dtype='<U10'),
#                 array(['stimPulses'], dtype='<U10'),
#                 array(['puffTone'], dtype='<U8'), array(['DBS'], dtype='<U3'),
#                 array(['BRstimTest'], dtype='<U10'),
#                 array(['stimPulses'], dtype='<U10')], dtype=object)           ,
#          array([array(['delSac'], dtype='<U6'),
#                 array(['BRstimTest'], dtype='<U10'),
#                 array(['stimPulses'], dtype='<U10'),
#                 array(['puffTone'], dtype='<U8'), array(['DBS'], dtype='<U3'),
#                 array(['BRstimTest'], dtype='<U10'),
#                 array(['stimPulses'], dtype='<U10')], dtype=object)           ,
#          array([array(['BRstimTest'], dtype='<U10'),
#                 array(['2delSac'], dtype='<U7'), array(['awakeDBS'], dtype='<U8'),
#                 array(['puffTone'], dtype='<U8'), array(['DBS'], dtype='<U3'),
#                 array(['stimPulses'], dtype='<U10'),
#                 array(['BRstimTest'], dtype='<U10'),
#                 array(['stimPulses'], dtype='<U10'), array(['OKN'], dtype='<U3')],
#                dtype=object)                                                      ,
#          array([array(['BRstimTest'], dtype='<U10'),
#                 array(['stimPulses'], dtype='<U10'),
#                 array(['2delSac'], dtype='<U7'), array(['puffTone'], dtype='<U8'),
#                 array(['DBS'], dtype='<U3')], dtype=object)                       ,
#          array([array(['BRstimTest'], dtype='<U10'),
#                 array(['stimPulses'], dtype='<U10'),
#                 array(['delSac'], dtype='<U6'), array(['puffTone'], dtype='<U8'),
#                 array(['DBS'], dtype='<U3'), array(['OKN'], dtype='<U3')],
#                dtype=object)                                                     ,
#          array([array(['BRstimTest'], dtype='<U10'),
#                 array(['2delSac'], dtype='<U7'), array(['puffTone'], dtype='<U8'),
#                 array(['DBS'], dtype='<U3'), array(['stimPulses'], dtype='<U10'),
#                 array(['BRstimTest'], dtype='<U10')], dtype=object)               ,
#          array([array(['puffTone'], dtype='<U8'), array(['DBS'], dtype='<U3'),
#                 array(['stimPulses'], dtype='<U10'),
#                 array(['BRstimTest'], dtype='<U10')], dtype=object)           ,
#          array([array(['puffTone'], dtype='<U8'), array(['DBS'], dtype='<U3')],
#                dtype=object)                                                   ,
#          array([array(['puffTone'], dtype='<U8'), array(['DBS'], dtype='<U3')],
#                dtype=object)                                                   ,
#          array([array(['puffTone'], dtype='<U8'), array(['DBS'], dtype='<U3')],
#                dtype=object)                                                   ,
#          array([array(['puffTone'], dtype='<U8'), array(['DBS'], dtype='<U3')],
#                dtype=object)                                                   ,
#          array([array(['puffTone'], dtype='<U8'), array(['DBS'], dtype='<U3')],
#                dtype=object)                                                   ,
#          array([array(['puffTone'], dtype='<U8'), array(['DBS'], dtype='<U3')],
#                dtype=object)                                                   ,
#          array([array(['awakeDBS'], dtype='<U8'),
#                 array(['stimPulses'], dtype='<U10'),
#                 array(['puffTone'], dtype='<U8'), array(['DBS'], dtype='<U3')],
#                dtype=object)                                                   ,
#          array([array(['puffTone'], dtype='<U8'), array(['DBS'], dtype='<U3'),
#                 array(['stimPulses'], dtype='<U10'),
#                 array(['stimPulses'], dtype='<U10')], dtype=object)           ,
#          array([array(['puffTone'], dtype='<U8'), array(['DBS'], dtype='<U3'),
#                 array(['stimPulses'], dtype='<U10'),
#                 array(['stimPulses'], dtype='<U10')], dtype=object)           ,
#          array([array(['puffTone'], dtype='<U8'), array(['DBS'], dtype='<U3'),
#                 array(['stimPulses'], dtype='<U10'),
#                 array(['stimPulses'], dtype='<U10')], dtype=object)           ,
#          array([array(['puffTone'], dtype='<U8'), array(['DBS'], dtype='<U3'),
#                 array(['stimPulses'], dtype='<U10')], dtype=object)           ,
#          array([array(['delSac'], dtype='<U6'), array(['visSac'], dtype='<U6'),
#                 array(['delSac'], dtype='<U6')], dtype=object)                 ,
#          array('delSac', dtype='<U6'), array('delSac', dtype='<U6'),
#          array('delSac', dtype='<U6'), array('delSac', dtype='<U6'),
#          array('delSac', dtype='<U6'), array('delSac', dtype='<U6'),
#          array('delSac', dtype='<U6'), array('delSac', dtype='<U6'),
#          array('delSac', dtype='<U6'), array('oddball', dtype='<U7'),
#          array('oddball', dtype='<U7'), array('oddball', dtype='<U7'),
#          array('oddball', dtype='<U7')], dtype=object),
#   'areas': array([array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['CPB'], dtype='<U3'), array(['7b'], dtype='<U2')],
#                dtype=object)                                               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ,
#          array([array(['vlPFC'], dtype='<U5'), array(['FEF'], dtype='<U3'),
#                 array(['7b'], dtype='<U2'), array(['CPB'], dtype='<U3'),
#                 array(['Thal'], dtype='<U4')], dtype=object)               ],
#         dtype=object),
#   'arrays': array([array([array(['PFC'], dtype='<U3'), array(['FEF'], dtype='<U3'),
#                 array(['PPC'], dtype='<U3'), array(['STG'], dtype='<U3')],
#                dtype=object)                                              ,
#          array([array(['PFC'], dtype='<U3'), array(['FEF'], dtype='<U3'),
#                 array(['PPC'], dtype='<U3'), array(['STG'], dtype='<U3')],
#                dtype=object)                                              ,
#          array([array(['PFC'], dtype='<U3'), array(['FEF'], dtype='<U3'),
#                 array(['PPC'], dtype='<U3'), array(['STG'], dtype='<U3')],
#                dtype=object)                                              ,
#          array([array(['PFC'], dtype='<U3'), array(['FEF'], dtype='<U3'),
#                 array(['PPC'], dtype='<U3'), array(['STG'], dtype='<U3')],
#                dtype=object)                                              ,
#          array([array(['PFC'], dtype='<U3'), array(['FEF'], dtype='<U3'),
#                 array(['PPC'], dtype='<U3'), array(['STG'], dtype='<U3')],
#                dtype=object)                                              ,
#          array([array(['PFC'], dtype='<U3'), array(['FEF'], dtype='<U3'),
#                 array(['PPC'], dtype='<U3'), array(['STG'], dtype='<U3')],
#                dtype=object)                                              ,
#          array([array(['PFC'], dtype='<U3'), array(['FEF'], dtype='<U3'),
#                 array(['PPC'], dtype='<U3'), array(['STG'], dtype='<U3')],
#                dtype=object)                                              ,
#          array([array(['PFC'], dtype='<U3'), array(['FEF'], dtype='<U3'),
#                 array(['PPC'], dtype='<U3'), array(['STG'], dtype='<U3')],
#                dtype=object)                                              ,
#          array([array(['PFC'], dtype='<U3'), array(['FEF'], dtype='<U3'),
#                 array(['PPC'], dtype='<U3'), array(['STG'], dtype='<U3')],
#                dtype=object)                                              ,
#          array([array(['PFC'], dtype='<U3'), array(['FEF'], dtype='<U3'),
# ...
#           array([], dtype='<U1')], dtype=object),
#    'VariableContinuity': array([], shape=(0, 0), dtype=uint8),
#    'RowNames': array([array(['MrJones-Anesthesia-20160105-01.002'], dtype='<U34'),
#           array(['MrJones-Anesthesia-20160105-01.003'], dtype='<U34'),
#           array(['MrJones-Anesthesia-20160105-01.004'], dtype='<U34'), ...,
#           array(['MrJones-Anesthesia-20161010-06.235'], dtype='<U34'),
#           array(['MrJones-Anesthesia-20161010-06.236'], dtype='<U34'),
#           array(['MrJones-Anesthesia-20161010-06.240'], dtype='<U34')],
#          dtype=object)}},
#  {'chnlID': array(['MrJones-Anesthesia-20160105-01.002',
#          'MrJones-Anesthesia-20160105-01.003',
#          'MrJones-Anesthesia-20160105-01.004', ...,
#          'MrJones-Anesthesia-20161010-06.microStim',
#          'MrJones-Anesthesia-20161010-06.LED',
#          'MrJones-Anesthesia-20161010-06.stimPulse'], dtype=object),
#   'electrode': array([ 2.,  3.,  4., ..., nan, nan, nan]),
#   'channel': array([124, 122, 120, ..., 129, 132, 136], dtype=uint8),
#   'chnlLabel': array(['elec2-2', 'elec2-3', 'elec2-4', ..., 'microStim', 'LED',
#          'StimPulse'], dtype=object),
#   'numSamples': array([12474902, 12474902, 12474902, ...,  2028517,  2028517,  2028517],
#         dtype=int32),
#   'smpRate': array([1000, 1000, 1000, ..., 1000, 1000, 1000], dtype=uint16),
#   'digitalRange': array([[-32764,  32764],
#          [-32764,  32764],
#          [-32764,  32764],
#          ...,
#          [-32767,  32767],
#          [-32767,  32767],
#          [-32767,  32767]], dtype=int16),
#   'd2aFactor': array([0.00025   , 0.00025   , 0.00025   , ..., 0.15259255, 0.15259255,
#          0.15259255]),
#   'analogRange': array([[   -8.191,     8.191],
#          [   -8.191,     8.191],
#          [   -8.191,     8.191],
#          ...,
#          [-5000.   ,  5000.   ],
#          [-5000.   ,  5000.   ],
#          [-5000.   ,  5000.   ]]),
#   'analogUnits': array(['mV', 'mV', 'mV', ..., 'uV', 'uV', 'uV'], dtype=object),
#   'filterCutoff': array([[2.50e-02, 3.00e+02],
#          [2.50e-02, 3.00e+02],
#          [2.50e-02, 3.00e+02],
#          ...,
#          [1.25e-02, 0.00e+00],
#          [0.00e+00, 0.00e+00],
#          [0.00e+00, 0.00e+00]]),
#   'isLFP': array([ True,  True,  True, ..., False, False, False]),
#   'isAIN': array([False, False, False, ...,  True,  True,  True]),
#   'session': array(['MrJones-Anesthesia-20160105-01', 'MrJones-Anesthesia-20160105-01',
#          'MrJones-Anesthesia-20160105-01', ...,
#          'MrJones-Anesthesia-20161010-06', 'MrJones-Anesthesia-20161010-06',
#          'MrJones-Anesthesia-20161010-06'], dtype=object),
#   'file': array(['anesthesia_20160105_PFC.ns2', 'anesthesia_20160105_PFC.ns2',
#          'anesthesia_20160105_PFC.ns2', ...,
#          'anesthesia_oddball_20161010_Thal.ns2',
#          'anesthesia_oddball_20161010_Thal.ns2',
#          'anesthesia_oddball_20161010_Thal.ns2'], dtype=object),
#   'Properties': {'Description': array('Analog channel information for session MrJones-Anesthesia-20160105-01',
#          dtype='<U69'),
#    'UserData': array([], shape=(0, 0), dtype=uint8),
#    'DimensionNames': array([array(['Channel'], dtype='<U7'), array(['Variable'], dtype='<U8')],
#          dtype=object),
#    'VariableNames': array([array(['chnlID'], dtype='<U6'), array(['electrode'], dtype='<U9'),
#           array(['channel'], dtype='<U7'), array(['chnlLabel'], dtype='<U9'),
#           array(['numSamples'], dtype='<U10'),
#           array(['smpRate'], dtype='<U7'),
#           array(['digitalRange'], dtype='<U12'),
#           array(['d2aFactor'], dtype='<U9'),
#           array(['analogRange'], dtype='<U11'),
#           array(['analogUnits'], dtype='<U11'),
#           array(['filterCutoff'], dtype='<U12'),
#           array(['isLFP'], dtype='<U5'), array(['isAIN'], dtype='<U5'),
#           array(['session'], dtype='<U7'), array(['file'], dtype='<U4')],
#          dtype=object),
#    'VariableDescriptions': array([array(['Unique analog channel identifier string'], dtype='<U39'),
#           array(['Electrode number (mapped from raw channel)'], dtype='<U42'),
#           array(['Raw recording system channel number'], dtype='<U35'),
#           array(['Recording system channel label'], dtype='<U30'),
#           array(['Total number of samples'], dtype='<U23'),
#           array(['Signal sampling frequency (Hz) of recorded data'], dtype='<U47'),
#           array(['Digital signal range ([lo,hi] in A/D units)'], dtype='<U43'),
#           array(['Digital to analog conversion factor'], dtype='<U35'),
#           array(['Analog signal range ([lo,hi] in "analogUnits")'], dtype='<U46'),
#           array(['Units that analogRange is given in'], dtype='<U34'),
#           array(['Filter cutoff freqs ([lo,hi] in Hz)'], dtype='<U35'),
#           array(['Is channel LFP/neural analog signal (1) or not (0)'], dtype='<U50'),
#           array(['Is channel auxiliary AnalogIn signal (1) or not (0)'],
#                 dtype='<U51')                                           ,
#           array(['SessionID string'], dtype='<U16'),
#           array(['Datafile channel was loaded from'], dtype='<U32')],
#          dtype=object),
#    'VariableUnits': array([array([], dtype='<U1'), array([], dtype='<U1'),
#           array([], dtype='<U1'), array([], dtype='<U1'),
#           array([], dtype='<U1'), array(['Hz'], dtype='<U2'),
#           array(['A/D'], dtype='<U3'), array([], dtype='<U1'),
#           array([], dtype='<U1'), array([], dtype='<U1'),
#           array(['Hz'], dtype='<U2'), array([], dtype='<U1'),
#           array([], dtype='<U1'), array([], dtype='<U1'),
#           array([], dtype='<U1')], dtype=object),
#    'VariableContinuity': array([], shape=(0, 0), dtype=uint8),
#    'RowNames': array([array(['MrJones-Anesthesia-20160105-01.002'], dtype='<U34'),
#           array(['MrJones-Anesthesia-20160105-01.003'], dtype='<U34'),
#           array(['MrJones-Anesthesia-20160105-01.004'], dtype='<U34'), ...,
#           array(['Row14691'], dtype='<U8'), array(['Row14692'], dtype='<U8'),
#           array(['Row14693'], dtype='<U8')], dtype=object)}},
#  {'electrode': array([  2,   3,   4, ..., 278, 279, 280], dtype=uint16),
#   'chnlID': array(['MrJones-Anesthesia-20160105-01.002',
#          'MrJones-Anesthesia-20160105-01.003',
#          'MrJones-Anesthesia-20160105-01.004', ...,
#          'MrJones-Anesthesia-20161010-06.278',
#          'MrJones-Anesthesia-20161010-06.279',
#          'MrJones-Anesthesia-20161010-06.280'], dtype=object),
#   'channel': array([124, 122, 120, ...,  54,  55,  56], dtype=uint8),
#   'session': array(['MrJones-Anesthesia-20160105-01', 'MrJones-Anesthesia-20160105-01',
#          'MrJones-Anesthesia-20160105-01', ...,
#          'MrJones-Anesthesia-20161010-06', 'MrJones-Anesthesia-20161010-06',
#          'MrJones-Anesthesia-20161010-06'], dtype=object),
#   'file': array(['anesthesia_20160105_PFC.ns2', 'anesthesia_20160105_PFC.ns2',
#          'anesthesia_20160105_PFC.ns2', ...,
#          'anesthesia_oddball_20161010_Thal.ns2',
#          'anesthesia_oddball_20161010_Thal.ns2',
#          'anesthesia_oddball_20161010_Thal.ns2'], dtype=object),
#   'hasLFP': array([ True,  True,  True, ...,  True,  True,  True]),
#   'numUnits': array([2, 1, 1, ..., 0, 0, 0], dtype=uint8),
#   'hemisphere': array(['right', 'right', 'right', ..., 'left', 'left', 'left'],
#         dtype=object),
#   'area': array(['vlPFC', 'vlPFC', 'vlPFC', ..., 'Thal', 'Thal', 'Thal'],
#         dtype=object),
#   'array': array(['PFC', 'PFC', 'PFC', ..., 'pThal', 'pThal', 'pThal'], dtype=object),
#   'NSP': array(['PFC', 'PFC', 'PFC', ..., 'Thal', 'Thal', 'Thal'], dtype=object),
#   'gridLoc': array([[7, 8],
#          [6, 8],
#          [5, 8],
#          ...,
#          [0, 4],
#          [0, 5],
#          [0, 6]], dtype=uint8),
#   'Properties': {'Description': array('Electrode metadata for session MrJones-Anesthesia-20160105-01',
#          dtype='<U61'),
#    'UserData': array([], shape=(0, 0), dtype=uint8),
#    'DimensionNames': array([array(['Electrode'], dtype='<U9'),
#           array(['Variable'], dtype='<U8')], dtype=object),
#    'VariableNames': array([array(['electrode'], dtype='<U9'), array(['chnlID'], dtype='<U6'),
#           array(['channel'], dtype='<U7'), array(['session'], dtype='<U7'),
#           array(['file'], dtype='<U4'), array(['hasLFP'], dtype='<U6'),
#           array(['numUnits'], dtype='<U8'),
#           array(['hemisphere'], dtype='<U10'), array(['area'], dtype='<U4'),
#           array(['array'], dtype='<U5'), array(['NSP'], dtype='<U3'),
#           array(['gridLoc'], dtype='<U7')], dtype=object),
#    'VariableDescriptions': array([array(['Electrode number (mapped from raw channel)'], dtype='<U42'),
#           array(['Unique analog channel identifier string'], dtype='<U39'),
#           array(['Raw recording system channel number'], dtype='<U35'),
#           array(['SessionID string'], dtype='<U16'),
#           array(['Datafile channel was loaded from'], dtype='<U32'),
#           array(['Electrode recorded usable LFP data (1) or not (0)'], dtype='<U49'),
#           array(['Number of channel units (not including unsorted)'], dtype='<U48'),
#           array(["Hemisphere recorded from ('left'|'right')"], dtype='<U41'),
#           array(["Area recorded from ('vlPFC'|'FEF'|'7b'|'CPB'|'Thal')"],
#                 dtype='<U52')                                            ,
#           array(["Array/DBS shank recorded from ('PFC'|'FEF'|'PPC'|'STG'|'aThal'|'pThal')"],
#                 dtype='<U71')                                                               ,
#           array(["Blackrock NSP recorded on ('PFC'|'PPCSTG'|'Thal')"], dtype='<U49'),
#           array(['Utah arrays: elec loc in array grid ([row,col]; (1,1)=upper-left, (8,8)=lower-right); DBS elecs: [~,depth]; 1=deepest, 6/8=most superficial contact'],
#                 dtype='<U147')                                                                                                                                          ],
#          dtype=object),
#    'VariableUnits': array([array([], dtype='<U1'), array([], dtype='<U1'),
#           array([], dtype='<U1'), array([], dtype='<U1'),
#           array([], dtype='<U1'), array([], dtype='<U1'),
#           array(['neurons'], dtype='<U7'), array([], dtype='<U1'),
#           array([], dtype='<U1'), array([], dtype='<U1'),
#           array([], dtype='<U1'), array([], dtype='<U1')], dtype=object),
#    'VariableContinuity': array([], shape=(0, 0), dtype=uint8),
#    'RowNames': array([array(['MrJones-Anesthesia-20160105-01.002'], dtype='<U34'),
#           array(['MrJones-Anesthesia-20160105-01.003'], dtype='<U34'),
#           array(['MrJones-Anesthesia-20160105-01.004'], dtype='<U34'), ...,
#           array(['Row13844'], dtype='<U8'), array(['Row13845'], dtype='<U8'),
#           array(['Row13846'], dtype='<U8')], dtype=object)}},
#  {'unitID': array(['MrJones-Anesthesia-20160105-01.002.00',
#          'MrJones-Anesthesia-20160105-01.002.01',
#          'MrJones-Anesthesia-20160105-01.002.02', ...,
#          'MrJones-Anesthesia-20161010-06.235.00',
#          'MrJones-Anesthesia-20161010-06.236.00',
#          'MrJones-Anesthesia-20161010-06.240.00'], dtype=object),
#   'electrode': array([  2,   2,   2, ..., 235, 236, 240], dtype=uint16),
#   'channel': array([124, 124, 124, ...,  85,  86,  81], dtype=uint8),
#   'unit': array([0, 1, 2, ..., 0, 0, 0], dtype=uint8),
#   'numSpikes': array([167457,  49457,  41932, ...,   3004,   5574,   2156], dtype=int32),
#   'chnlID': array(['MrJones-Anesthesia-20160105-01.002',
#          'MrJones-Anesthesia-20160105-01.002',
#          'MrJones-Anesthesia-20160105-01.002', ...,
#          'MrJones-Anesthesia-20161010-06.235',
#          'MrJones-Anesthesia-20161010-06.236',
#          'MrJones-Anesthesia-20161010-06.240'], dtype=object),
#   'session': array(['MrJones-Anesthesia-20160105-01', 'MrJones-Anesthesia-20160105-01',
#          'MrJones-Anesthesia-20160105-01', ...,
#          'MrJones-Anesthesia-20161010-06', 'MrJones-Anesthesia-20161010-06',
#          'MrJones-Anesthesia-20161010-06'], dtype=object),
#   'file': array(['anesthesia_20160105_PFC-SORTED.nev',
#          'anesthesia_20160105_PFC-SORTED.nev',
#          'anesthesia_20160105_PFC-SORTED.nev', ...,
#          'anesthesia_oddball_20161010_PPCSTG-SORTED.nev',
#          'anesthesia_oddball_20161010_PPCSTG-SORTED.nev',
#          'anesthesia_oddball_20161010_PPCSTG-SORTED.nev'], dtype=object),
#   'hemisphere': array(['right', 'right', 'right', ..., 'right', 'right', 'right'],
#         dtype=object),
#   'area': array(['vlPFC', 'vlPFC', 'vlPFC', ..., 'CPB', 'CPB', 'CPB'], dtype=object),
#   'array': array(['PFC', 'PFC', 'PFC', ..., 'STG', 'STG', 'STG'], dtype=object),
#   'NSP': array(['PFC', 'PFC', 'PFC', ..., 'PPCSTG', 'PPCSTG', 'PPCSTG'],
#         dtype=object),
#   'gridLoc': array([[7, 8],
#          [7, 8],
#          [7, 8],
#          ...,
#          [6, 3],
#          [5, 3],
#          [1, 3]], dtype=uint8),
#   'Properties': {'Description': array('Unit metadata for session MrJones-Anesthesia-20160105-01',
#          dtype='<U56'),
#    'UserData': array([], shape=(0, 0), dtype=uint8),
#    'DimensionNames': array([array(['Unit'], dtype='<U4'), array(['Variable'], dtype='<U8')],
#          dtype=object),
#    'VariableNames': array([array(['unitID'], dtype='<U6'), array(['electrode'], dtype='<U9'),
#           array(['channel'], dtype='<U7'), array(['unit'], dtype='<U4'),
#           array(['numSpikes'], dtype='<U9'), array(['chnlID'], dtype='<U6'),
#           array(['session'], dtype='<U7'), array(['file'], dtype='<U4'),
#           array(['hemisphere'], dtype='<U10'), array(['area'], dtype='<U4'),
#           array(['array'], dtype='<U5'), array(['NSP'], dtype='<U3'),
#           array(['gridLoc'], dtype='<U7')], dtype=object),
#    'VariableDescriptions': array([array(['Unique unit identifier string'], dtype='<U29'),
#           array(['Electrode number unit recorded on'], dtype='<U33'),
#           array(['Raw channel number unit recorded on'], dtype='<U35'),
#           array(['Unit number within electrode (0=unsorted spikes)'], dtype='<U48'),
#           array(['Total number of unit spikes'], dtype='<U27'),
#           array(['Spiking channel identifier string'], dtype='<U33'),
#           array(['SessionID string'], dtype='<U16'),
#           array(['Datafile channel was loaded from'], dtype='<U32'),
#           array(["Hemisphere recorded from ('left'|'right')"], dtype='<U41'),
#           array(["Area recorded from ('vlPFC'|'FEF'|'7b'|'CPB'|'Thal')"],
#                 dtype='<U52')                                            ,
#           array(["Array/DBS shank recorded from ('PFC'|'FEF'|'PPC'|'STG'|'aThal'|'pThal')"],
#                 dtype='<U71')                                                               ,
#           array(["Blackrock NSP recorded on ('PFC'|'PPCSTG'|'Thal')"], dtype='<U49'),
#           array(['Utah arrays: elec loc in array grid ([row,col]; (1,1)=upper-left, (8,8)=lower-right); DBS elecs: [~,depth]; 1=deepest, 6/8=most superficial contact'],
#                 dtype='<U147')                                                                                                                                          ],
#          dtype=object),
#    'VariableUnits': array([array([], dtype='<U1'), array([], dtype='<U1'),
#           array([], dtype='<U1'), array([], dtype='<U1'),
#           array(['spikes'], dtype='<U6'), array([], dtype='<U1'),
#           array([], dtype='<U1'), array([], dtype='<U1'),
#           array([], dtype='<U1'), array([], dtype='<U1'),
#           array([], dtype='<U1'), array([], dtype='<U1'),
#           array([], dtype='<U1')], dtype=object),
#    'VariableContinuity': array([], shape=(0, 0), dtype=uint8),
#    'RowNames': array([array(['MrJones-Anesthesia-20160105-01.002.00'], dtype='<U37'),
#           array(['MrJones-Anesthesia-20160105-01.002.01'], dtype='<U37'),
#           array(['MrJones-Anesthesia-20160105-01.002.02'], dtype='<U37'),
#           ...,
#           array(['MrJones-Anesthesia-20161010-06.235.00'], dtype='<U37'),
#           array(['MrJones-Anesthesia-20161010-06.236.00'], dtype='<U37'),
#           array(['MrJones-Anesthesia-20161010-06.240.00'], dtype='<U37')],
#          dtype=object)}})

# %% [markdown]
# # Run

# %%
# --------
# User-guided SLDS parameters
# --------
latent_dim = 2 # number of latent dimensions
# transitions = "standard" # transition class
transitions = "standard"
stride = 10*60 # s
duration = 10*60 # s

length = int(duration/dt)
# start_times = np.arange(0, lfp.shape[0]*dt - duration + 0.1, stride).astype(int)
start_times = np.arange(0, lfp.shape[0]*dt - duration - 0.1, stride).astype(int)
start_times = np.hstack([start_times, lfp.shape[0]*dt - duration - 5])

# areas = ['vlPFC', 'FEF', 'CPB', '7b']
# areas = np.unique(electrode_info['area'])
areas = ['vlPFC']
unit_indices = np.arange(lfp.shape[1])[pd.Series(electrode_info['area']).isin(areas)]
var_names = [f"unit_{unit_num} {electrode_info['area'][unit_num]}" for unit_num in unit_indices]

# --------
# Set the parameters of the SLDS
# --------
emissions_dim = len(unit_indices)     # number of observed dimensions

data_dir = "../../__data__/slds/"
t = time.localtime()
timestamp = time.strftime('%b-%d-%Y_%H%M', t)
data_dir = os.path.join(data_dir, f"slds_big_run_latent_{latent_dim}_duration_{duration}_stride_{stride}_{timestamp}")
os.makedirs(data_dir, exist_ok=True)

# %%
anesthesia_bounds = [session_info['drugStart'][0], session_info['drugEnd'][1]]
param_list = []
for start_time in start_times:

    # --------
    # Set Disc States for Each Segment
    # --------
    piece_bounds = [start_time, start_time + duration]
    if piece_bounds[1] <= anesthesia_bounds[0] or piece_bounds[0] >= anesthesia_bounds[1]:
        # WAKEFUL
        n_disc_states = 2
    elif piece_bounds[1] > anesthesia_bounds[0] and piece_bounds[1] <= anesthesia_bounds[1]:
        if piece_bounds[0] < anesthesia_bounds[0]:
            # TRANSITION TO ANESTHESIA
            n_disc_states = 2
        else: # piece_bounds[0] >= anesthesia_bounds
            # FULL ANESTHESIA
            n_disc_states = 2
    else: # piece_bounds[0] > anesthesia_bounds[1] and piece_bounds[1] > anesthesia_bounds[1]
        # TRANSITION OUT OF ANESTHESIA
        n_disc_states = 2

    start_step = int(start_time/dt)
    data = lfp[start_step:start_step + length, unit_indices]
    param_list.append((start_time, start_step, data, transitions, emissions_dim, n_disc_states, latent_dim, data_dir))

# %%
for param_tuple in tqdm(param_list):
    slds_eigs_worker(param_tuple, savefile=True, verbose=2)
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
t = np.arange(results['start_time'], results['start_time'] + duration, dt)
# plt.fill_between(t, 0, 1, where=results['disc_states'])
plt.fill_between(t, 0, 1, where=airPuff_binary[results['start_step']:results['start_step'] + length], color='green', alpha=0.4)
plt.fill_between(t, 0, 1, where=audio_binary[results['start_step']:results['start_step'] + length], color='red', alpha=0.4)
plt.show()

# %% [markdown]
# # Analyze

# %%
# %%time
data_dir = "/home/adameisen/Documents/MIT/code/ChaoticConsciousness/__data__/slds/slds_big_run_latent_2_duration_5_stride_5_Oct-28-2021_1833"
vis
# Out:
# CPU times: user 893 ms, sys: 3.99 s, total: 4.89 s
# Wall time: 25.9 s

# %%
duration = 5
stride = 5
n_disc_states = 2
latent_dim = 2
stride = duration

# %%
# fig, axs = plt.subplots(2, 1, figsize=(14, 8))

# ax = axs[0]
# start_times = results.start_time
# mean_eigs = np.array([mat.mean() for mat in results.criticality_inds])
# ax.plot(start_times, mean_eigs)
# ax.set_xlabel('Time (s)', fontsize=14)
# ax.set_ylabel('Mean Criticality Index', fontsize=14)
# ax.set_title("Mean Across Discrete States", fontsize=14)
# ax.fill_between(np.arange(session_info['drugStart'][0], session_info['drugEnd'][0], dt), 
#                             mean_eigs.min(), mean_eigs.max(), color='plum', alpha=0.2, label='drug infusion 1')
# ax.fill_between(np.arange(session_info['drugStart'][1], session_info['drugEnd'][1], dt), 
#                             mean_eigs.min(), mean_eigs.max(), color='darkorchid', alpha=0.2, label='drug infusion 2')
# # ax.legend()

# ax = axs[1]
# mean_eigs = np.array([mat.mean(axis=1) for mat in results.criticality_inds])
# for i in range(n_disc_states):
#     ax.plot(start_times, mean_eigs[:, i], label=f'discrete state {i}')
# ax.set_xlabel('Time (s)', fontsize=14)
# # ax.set_ylabel('Mean Eigenvalue')
# ax.set_title("Mean for Each Discrete State", fontsize=14)
# ax.fill_between(np.arange(session_info['drugStart'][0], session_info['drugEnd'][0], dt), 
#                             mean_eigs.min(), mean_eigs.max(), color='C6', alpha=0.2, label='drug infusion 1')
# ax.fill_between(np.arange(session_info['drugStart'][1], session_info['drugEnd'][1], dt), 
#                             mean_eigs.min(), mean_eigs.max(), color='C7', alpha=0.2, label='drug infusion 2')

# plt.axvline(session_info['eyesClose'][-1]/60 if isinstance(session_info['eyesClose'], np.ndarray) else session_info['eyesClose']/60, linestyle='--', c='red', label="loss of consciousness")
# plt.axvline(session_info['eyesOpen'][-1]/60 if isinstance(session_info['eyesOpen'], np.ndarray) else session_info['eyesOpen']/60, linestyle='--', c='green', label="return of consciousness")

# ax.legend()
# ax.yaxis.set_tick_params(labelbottom=True)
# ax.set_ylabel('Mean Criticality Index', fontsize=14)

# # # make coloured portions the same size
# # ax = axs[0]
# # ax.fill_between(np.arange(session_info['drugStart'][0], session_info['drugEnd'][0], dt), 
# #                             mean_eigs.min(), mean_eigs.max(), color='plum', alpha=0.2, label='drug infusion 1')
# # ax.fill_between(np.arange(session_info['drugStart'][1], session_info['drugEnd'][1], dt), 
# #                             mean_eigs.min(), mean_eigs.max(), color='darkorchid', alpha=0.2, label='drug infusion 2')
# # ax.legend()

# plt.suptitle(f"Mean Criticality Index of SLDS Transition Matrix\nLatent Dim = {latent_dim}, Window = {duration} s", fontsize=18)
# plt.tight_layout()
# plt.show()

# %%
fig = plt.figure(figsize=(14, 8))

ax = plt.gca()
start_times = results.start_time/60
# mean_eigs = np.array([mat.mean() for mat in results.criticality_inds])
mean_eigs = np.zeros(len(results))
for i in range(len(results)):
    disc_states, counts = np.unique(results.disc_states.iloc[i], return_counts=True)
    mean_crit = 0
    for disc_state, count in zip(disc_states, counts):
        mean_crit += (count/np.sum(counts))*results.criticality_inds.iloc[i][disc_state].mean()
    mean_eigs[i] = mean_crit
ax.plot(start_times, mean_eigs, label='vlPFC')
ax.set_xlabel('Time (min)', fontsize=14)
ax.set_ylabel('Mean Criticality Index', fontsize=14)
ax.set_title("Mean Across Discrete States", fontsize=14)
min_val = mean_eigs.min()
max_val = mean_eigs.max()
ax.fill_between(np.arange(session_info['drugStart'][0], session_info['drugEnd'][0], stride)/60, 
                        min_val, max_val, color='plum', alpha=0.2, label=f"drug infusion 1 - dose = {session_info['drugDose'][0]}")
ax.fill_between(np.arange(session_info['drugStart'][1], session_info['drugEnd'][1], stride)/60, 
                        min_val, max_val, color='darkorchid', alpha=0.2, label=f"drug infusion 1 - dose = {session_info['drugDose'][1]}")

plt.axvline(session_info['eyesClose'][-1]/60 if isinstance(session_info['eyesClose'], np.ndarray) else session_info['eyesClose']/60, linestyle='--', c='red', label="loss of consciousness")
plt.axvline(session_info['eyesOpen'][-1]/60 if isinstance(session_info['eyesOpen'], np.ndarray) else session_info['eyesOpen']/60, linestyle='--', c='green', label="return of consciousness")
ax.legend()
plt.suptitle(f"Mean Criticality Index of SLDS Transition Matrix\nLatent Dim = {latent_dim}, Window = {duration} s", fontsize=18)
plt.show()

# %%
len(results)
# Out:
# 1417

# %%
unit_indices = run_params['unit_indices']
length = run_params['length']
n_samp = 10
T_samp = 1000

interval = 5 # number of windows to use
indices = np.arange(len(results) - 1)
indices = [i for i in indices if i % 5 == 0]

start_times = np.zeros(len(indices))

prediction_mse = np.zeros((len(indices), len(ts), T_samp))
for num, index in enumerate(tqdm(indices)):
    row = results.iloc[index]
    start_times[num] = row.start_time
    
    slds = row.slds
    start_step = row.start_step
    ts = [results.iloc[index + 1].start_step]
#     ts = [results.iloc[index + 800].start_step]
#     print(results.iloc[index + 800].start_time)

    for i, t in enumerate(ts):
        elbo_test,q_test= slds.approximate_posterior(lfp[t-length+1:t+1, unit_indices], num_iters=10, verbose=False) 
        x_test=q_test.mean_continuous_states[0][-1:]
        z_test=np.argmax(q_test.mean_discrete_states[0][-1:],axis=1)

        for n in range(n_samp):
            [z_pred,x_pred,y_pred]=slds.sample(T_samp, prefix=(z_test,x_test,lfp[t:t+1, unit_indices]))
    #         y_pred_current = slds.smooth(x_test, lfp[t:t+1, unit_indices])
            prediction_mse[num][i] += ((y_pred - lfp[t+1:t + T_samp + 1, unit_indices])**2).mean(axis=1)

        prediction_mse[num] /= n_samp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a578dbcb693b> in <module>
# ----> 1 unit_indices = run_params['unit_indices']
#       2 length = run_params['length']
#       3 n_samp = 10
#       4 T_samp = 1000
#       5
#
# NameError: name 'run_params' is not defined

# %%
plt.plot(prediction_mse[0][0])
plt.xlabel('Steps Ahead')
plt.title('Prediction Squared Error Averaged Across Neurons')
plt.show()

# %%
plt.plot(prediction_mse[0][0])
plt.xlabel('Steps Ahead')
plt.title('Prediction Squared Error Averaged Across Neurons (Test During Anesthesia)')
plt.show()

# %%
plt.plot(prediction_mse[:10, :].mean(axis=2))
