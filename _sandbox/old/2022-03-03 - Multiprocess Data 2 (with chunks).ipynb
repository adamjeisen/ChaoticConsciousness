# %%
# %load_ext autoreload

# %%
# %autoreload 2
from collections import defaultdict
from datetime import datetime
import h5py
import matplotlib.pyplot as plt
from neural_analysis.matIO import loadmat
import numpy as np
import os
import pandas as pd
import re
from scipy.signal import butter, filtfilt, freqz
import shutil
from sklearn.metrics import r2_score
import sys
import time
from tqdm.auto import tqdm

sys.path.append('..')
from utils import compile_folder, get_data_class, get_result_path, load_window_from_chunks, load, save, save_lfp_chunks

# %% [markdown]
# ## Multiprocessing

# %%
all_data_dir = f"/om/user/eisenaj/datasets/anesthesia/mat"
task_type = 'VAR'
# data_class = 'propofolPuffTone'
data_class = 'propofolWakeup'
windows = [int(w) if w % 1 == 0 else w for w in np.arange(0.5, 10.5, 0.5)]
# bandpass_info = dict(
#     flag=False,
#     low=None,
#     high=None
# )
# bandpass_info = dict(
#     flag=True,
#     low=0.5,
#     high=100
# )

# %%
# print(f"BANDPASS = {bandpass_info['flag']}")
for session in [f[:-4] for f in os.listdir(os.path.join(all_data_dir, data_class)) if f.endswith('.mat')][1:]:
# for session in ['MrJones-Anesthesia-20160107-01']:
# for session in ['SPOCK_Ketamine_20210909']:
    data_class = get_data_class(session, all_data_dir)
    print("="*25)
    print(f"session = {session}")
    print("-"*25)
#     

    regex = re.compile(f"{session}_lfp_chunked_.*")
    data_dir = None
    chunk_time = np.Inf
    for f in os.listdir(os.path.join(all_data_dir, data_class)):
        if regex.match(f):
            if int(f.split('_')[-1][:-1]) < chunk_time:
                data_dir = os.path.join(all_data_dir, data_class, f)
                chunk_time = int(f.split('_')[-1][:-1])
    if data_dir is None:
        print("session has not been chunked, chunking now")
        save_lfp_chunks(session, all_data_dir)
    else:
        print("session has been chunked")
    
    
    results_dir = f"/om/user/eisenaj/ChaoticConsciousness/results/{data_class}/{task_type}"
    windows_to_run = []
    for window in windows:
        try:
#             get_result_path(results_dir, session, window, bandpass_info=bandpass_info)
            get_result_path(results_dir, session, window)
        except:
            windows_to_run.append(window)
            
    if len(windows_to_run) == 0:
        print(f"All windows have been run: {windows}")
    else:
        print(f"Now running: {windows_to_run}")
    
        for window in windows_to_run:
            stride = window
#             os.system(f"sbatch /om2/user/eisenaj/code/ChaoticConsciousness/shell_scripts/multiproc.sh {session} {window} {stride} {task_type} {1 if bandpass_info['flag'] else 0} {bandpass_info['low']} {bandpass_info['high']}")
            os.system(f"sbatch /om2/user/eisenaj/code/ChaoticConsciousness/shell_scripts/multiproc.sh {session} {window} {stride} {task_type}")
# Out:
# =========================
# session = MrJones-Anesthesia-20160601-02
# -------------------------
# session has been chunked
# Now running: [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
# Submitted batch job 24053823
# Submitted batch job 24053824
# Submitted batch job 24053825
# Submitted batch job 24053826
# Submitted batch job 24053827
# Submitted batch job 24053828
# Submitted batch job 24053829
# Submitted batch job 24053830
# Submitted batch job 24053831
# Submitted batch job 24053832
# Submitted batch job 24053833
# Submitted batch job 24053834
# Submitted batch job 24053836
# Submitted batch job 24053837
# Submitted batch job 24053838
# Submitted batch job 24053839
# Submitted batch job 24053840
# Submitted batch job 24053841
# Submitted batch job 24053842
# Submitted batch job 24053843
# =========================
# session = MrJones-Anesthesia-20160520-01
# -------------------------
# session has been chunked
# Now running: [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
# Submitted batch job 24053844
# Submitted batch job 24053845
# Submitted batch job 24053846
# Submitted batch job 24053847
# Submitted batch job 24053848
# Submitted batch job 24053849
# Submitted batch job 24053850
# Submitted batch job 24053851
# Submitted batch job 24053852
# Submitted batch job 24053853
# Submitted batch job 24053854
# Submitted batch job 24053855
# Submitted batch job 24053856
# Submitted batch job 24053857
# Submitted batch job 24053858
# Submitted batch job 24053859
# Submitted batch job 24053860
# Submitted batch job 24053861
# Submitted batch job 24053862
# Submitted batch job 24053863
# =========================
# session = MrJones-Anesthesia-20160527-03
# -------------------------
# session has been chunked
# Now running: [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
# Submitted batch job 24053864
# Submitted batch job 24053865
# Submitted batch job 24053866
# Submitted batch job 24053867
# Submitted batch job 24053868
# Submitted batch job 24053869
# Submitted batch job 24053870
# Submitted batch job 24053871
# Submitted batch job 24053872
# Submitted batch job 24053873
# Submitted batch job 24053874
# Submitted batch job 24053875
# Submitted batch job 24053876
# Submitted batch job 24053877
# Submitted batch job 24053878
# Submitted batch job 24053879
# Submitted batch job 24053880
# Submitted batch job 24053881
# Submitted batch job 24053882
# Submitted batch job 24053883
# =========================
# session = Mary-Anesthesia-20161229-02
# -------------------------
# session has been chunked
# Now running: [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
# Submitted batch job 24053884
# Submitted batch job 24053885
# Submitted batch job 24053886
# Submitted batch job 24053887
# Submitted batch job 24053888
# Submitted batch job 24053889
# Submitted batch job 24053890
# Submitted batch job 24053891
# Submitted batch job 24053892
# Submitted batch job 24053893
# Submitted batch job 24053894
# Submitted batch job 24053895
# Submitted batch job 24053896
# Submitted batch job 24053897
# Submitted batch job 24053898
# Submitted batch job 24053899
# Submitted batch job 24053900
# Submitted batch job 24053901
# Submitted batch job 24053902
# Submitted batch job 24053903
# =========================
# session = Mary-Anesthesia-20170123-02
# -------------------------
# session has been chunked
# Now running: [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
# Submitted batch job 24053904
# Submitted batch job 24053905
# Submitted batch job 24053906
# Submitted batch job 24053907
# Submitted batch job 24053908
# Submitted batch job 24053909
# Submitted batch job 24053910
# Submitted batch job 24053911
# Submitted batch job 24053912
# Submitted batch job 24053913
# Submitted batch job 24053914
# Submitted batch job 24053915
# Submitted batch job 24053916
# Submitted batch job 24053917
# Submitted batch job 24053918
# Submitted batch job 24053919
# Submitted batch job 24053920
# Submitted batch job 24053921
# Submitted batch job 24053922
# Submitted batch job 24053923
# =========================
# session = Mary-Anesthesia-20170105-02
# -------------------------
# session has been chunked
# Now running: [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
# Submitted batch job 24053924
# Submitted batch job 24053925
# Submitted batch job 24053926
# Submitted batch job 24053927
# Submitted batch job 24053928
# Submitted batch job 24053929
# Submitted batch job 24053930
# Submitted batch job 24053931
# Submitted batch job 24053932
# Submitted batch job 24053933
# Submitted batch job 24053934
# Submitted batch job 24053935
# Submitted batch job 24053936
# Submitted batch job 24053937
# Submitted batch job 24053938
# Submitted batch job 24053939
# Submitted batch job 24053940
# Submitted batch job 24053941
# Submitted batch job 24053942
# Submitted batch job 24053943
# =========================
# session = MrJones-Anesthesia-20160425-01
# -------------------------
# session has been chunked
# Now running: [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
# Submitted batch job 24053944
# Submitted batch job 24053945
# Submitted batch job 24053946
# Submitted batch job 24053947
# Submitted batch job 24053948
# Submitted batch job 24053949
# Submitted batch job 24053950
# Submitted batch job 24053951
# Submitted batch job 24053952
# Submitted batch job 24053953
# Submitted batch job 24053954
# Submitted batch job 24053955
# Submitted batch job 24053956
# Submitted batch job 24053957
# Submitted batch job 24053958
# Submitted batch job 24053959
# Submitted batch job 24053960
# Submitted batch job 24053961
# Submitted batch job 24053962
# Submitted batch job 24053963
# =========================
# session = Mary-Anesthesia-20170127-03
# -------------------------
# session has been chunked
# Now running: [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
# Submitted batch job 24053964
# Submitted batch job 24053965
# Submitted batch job 24053966
# Submitted batch job 24053967
# Submitted batch job 24053968
# Submitted batch job 24053969
# Submitted batch job 24053970
# Submitted batch job 24053971
# Submitted batch job 24053972
# Submitted batch job 24053973
# Submitted batch job 24053974
# Submitted batch job 24053975
# Submitted batch job 24053976
# Submitted batch job 24053977
# Submitted batch job 24053978
# Submitted batch job 24053979
# Submitted batch job 24053980
# Submitted batch job 24053981
# Submitted batch job 24053982
# Submitted batch job 24053983
# =========================
# session = MrJones-Anesthesia-20160412-01
# -------------------------
# session has been chunked
# Now running: [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
# Submitted batch job 24053984
# Submitted batch job 24053985
# Submitted batch job 24053986
# Submitted batch job 24053987
# Submitted batch job 24053988
# Submitted batch job 24053989
# Submitted batch job 24053990
# Submitted batch job 24053991
# Submitted batch job 24053992
# Submitted batch job 24053993
# Submitted batch job 24053994
# Submitted batch job 24053995
# Submitted batch job 24053996
# Submitted batch job 24053997
# Submitted batch job 24053998
# Submitted batch job 24053999
# Submitted batch job 24054000
# Submitted batch job 24054001
# Submitted batch job 24054002
# Submitted batch job 24054003
# =========================
# session = Mary-Anesthesia-20170118-02
# -------------------------
# session has been chunked
# Now running: [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
# Submitted batch job 24054004
# Submitted batch job 24054005
# Submitted batch job 24054006
# Submitted batch job 24054007
# Submitted batch job 24054008
# Submitted batch job 24054009
# Submitted batch job 24054010
# Submitted batch job 24054011
# Submitted batch job 24054012
# Submitted batch job 24054013
# Submitted batch job 24054014
# Submitted batch job 24054015
# Submitted batch job 24054016
# Submitted batch job 24054017
# Submitted batch job 24054018
# Submitted batch job 24054019
# Submitted batch job 24054020
# Submitted batch job 24054021
# Submitted batch job 24054022
# Submitted batch job 24054023
# =========================
# session = MrJones-Anesthesia-20160509-01
# -------------------------
# session has been chunked
# Now running: [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
# Submitted batch job 24054024
# Submitted batch job 24054025
# Submitted batch job 24054026
# Submitted batch job 24054027
# Submitted batch job 24054028
# Submitted batch job 24054029
# Submitted batch job 24054030
# Submitted batch job 24054031
# Submitted batch job 24054032
# Submitted batch job 24054033
# Submitted batch job 24054034
# Submitted batch job 24054035
# Submitted batch job 24054036
# Submitted batch job 24054037
# Submitted batch job 24054038
# Submitted batch job 24054039
# Submitted batch job 24054040
# Submitted batch job 24054041
# Submitted batch job 24054042
# Submitted batch job 24054043
# =========================
# session = Mary-Anesthesia-20170130-03
# -------------------------
# session has been chunked
# Now running: [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
# Submitted batch job 24054044
# Submitted batch job 24054045
# Submitted batch job 24054046
# Submitted batch job 24054047
# Submitted batch job 24054048
# Submitted batch job 24054049
# Submitted batch job 24054050
# Submitted batch job 24054051
# Submitted batch job 24054052
# Submitted batch job 24054053
# Submitted batch job 24054054
# Submitted batch job 24054055
# Submitted batch job 24054056
# Submitted batch job 24054057
# Submitted batch job 24054058
# Submitted batch job 24054059
# Submitted batch job 24054060
# Submitted batch job 24054061
# Submitted batch job 24054062
# Submitted batch job 24054063
# =========================
# session = MrJones-Anesthesia-20160421-01
# -------------------------
# session has been chunked
# Now running: [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
# Submitted batch job 24054064
# Submitted batch job 24054065
# Submitted batch job 24054066
# Submitted batch job 24054067
# Submitted batch job 24054068
# Submitted batch job 24054069
# Submitted batch job 24054070
# Submitted batch job 24054071
# Submitted batch job 24054072
# Submitted batch job 24054073
# Submitted batch job 24054074
# Submitted batch job 24054075
# Submitted batch job 24054076
# Submitted batch job 24054077
# Submitted batch job 24054078
# Submitted batch job 24054079
# Submitted batch job 24054080
# Submitted batch job 24054081
# Submitted batch job 24054082
# Submitted batch job 24054083
# =========================
# session = MrJones-Anesthesia-20160414-01
# -------------------------
# session has been chunked
# Now running: [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
# Submitted batch job 24054084
# Submitted batch job 24054085
# Submitted batch job 24054086
# Submitted batch job 24054087
# Submitted batch job 24054088
# Submitted batch job 24054089
# Submitted batch job 24054090
# Submitted batch job 24054091
# Submitted batch job 24054092
# Submitted batch job 24054093
# Submitted batch job 24054094
# Submitted batch job 24054095
# Submitted batch job 24054096
# Submitted batch job 24054097
# Submitted batch job 24054098
# Submitted batch job 24054099
# Submitted batch job 24054100
# Submitted batch job 24054101
# Submitted batch job 24054102
# Submitted batch job 24054103
# =========================
# session = MrJones-Anesthesia-20160518-01
# -------------------------
# session has been chunked
# Now running: [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
# Submitted batch job 24054104
# Submitted batch job 24054105
# Submitted batch job 24054106
# Submitted batch job 24054107
# Submitted batch job 24054108
# Submitted batch job 24054109
# Submitted batch job 24054110
# Submitted batch job 24054111
# Submitted batch job 24054112
# Submitted batch job 24054113
# Submitted batch job 24054114
# Submitted batch job 24054115
# Submitted batch job 24054116
# Submitted batch job 24054117
# Submitted batch job 24054118
# Submitted batch job 24054119
# Submitted batch job 24054120
# Submitted batch job 24054121
# Submitted batch job 24054122
# Submitted batch job 24054123
# =========================
# session = Mary-Anesthesia-20170113-02
# -------------------------
# session has been chunked
# Now running: [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
# Submitted batch job 24054124
# Submitted batch job 24054125
# Submitted batch job 24054126
# Submitted batch job 24054127
# Submitted batch job 24054128
# Submitted batch job 24054129
# Submitted batch job 24054130
# Submitted batch job 24054131
# Submitted batch job 24054132
# Submitted batch job 24054133
# Submitted batch job 24054134
# Submitted batch job 24054135
# Submitted batch job 24054136
# Submitted batch job 24054137
# Submitted batch job 24054138
# Submitted batch job 24054139
# Submitted batch job 24054140
# Submitted batch job 24054141
# Submitted batch job 24054142
# Submitted batch job 24054143
# =========================
# session = Mary-Anesthesia-20170201-03
# -------------------------
# session has been chunked
# Now running: [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
# Submitted batch job 24054144
# Submitted batch job 24054145
# Submitted batch job 24054146
# Submitted batch job 24054147
# Submitted batch job 24054148
# Submitted batch job 24054149
# Submitted batch job 24054150
# Submitted batch job 24054151
# Submitted batch job 24054152
# Submitted batch job 24054153
# Submitted batch job 24054154
# Submitted batch job 24054155
# Submitted batch job 24054156
# Submitted batch job 24054157
# Submitted batch job 24054158
# Submitted batch job 24054159
# Submitted batch job 24054160
# Submitted batch job 24054161
# Submitted batch job 24054162
# Submitted batch job 24054163
# =========================
# session = MrJones-Anesthesia-20160423-02
# -------------------------
# session has been chunked
# Now running: [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
# Submitted batch job 24054164
# Submitted batch job 24054165
# Submitted batch job 24054166
# Submitted batch job 24054167
# Submitted batch job 24054168
# Submitted batch job 24054169
# Submitted batch job 24054170
# Submitted batch job 24054171
# Submitted batch job 24054172
# Submitted batch job 24054173
# Submitted batch job 24054174
# Submitted batch job 24054175
# Submitted batch job 24054176
# Submitted batch job 24054177
# Submitted batch job 24054178
# Submitted batch job 24054179
# Submitted batch job 24054180
# Submitted batch job 24054181
# Submitted batch job 24054182
# Submitted batch job 24054183
# =========================
# session = Mary-Anesthesia-20170120-02
# -------------------------
# session has been chunked
# Now running: [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
# Submitted batch job 24054184
# Submitted batch job 24054185
# Submitted batch job 24054186
# Submitted batch job 24054187
# Submitted batch job 24054188
# Submitted batch job 24054189
# Submitted batch job 24054190
# Submitted batch job 24054191
# Submitted batch job 24054192
# Submitted batch job 24054193
# Submitted batch job 24054194
# Submitted batch job 24054195
# Submitted batch job 24054196
# Submitted batch job 24054197
# Submitted batch job 24054198
# Submitted batch job 24054199
# Submitted batch job 24054200
# Submitted batch job 24054201
# Submitted batch job 24054202
# Submitted batch job 24054203
# =========================
# session = MrJones-Anesthesia-20160513-01
# -------------------------
# session has been chunked
# Now running: [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
# Submitted batch job 24054204
# Submitted batch job 24054205
# Submitted batch job 24054206
# Submitted batch job 24054207
# Submitted batch job 24054208
# Submitted batch job 24054209
# Submitted batch job 24054210
# Submitted batch job 24054211
# Submitted batch job 24054212
# Submitted batch job 24054213
# Submitted batch job 24054214
# Submitted batch job 24054215
# Submitted batch job 24054216
# Submitted batch job 24054217
# Submitted batch job 24054218
# Submitted batch job 24054219
# Submitted batch job 24054220
# Submitted batch job 24054221
# Submitted batch job 24054222
# Submitted batch job 24054223

# %% [markdown]
# ## Fix Broken Compile

# %%
dt = 0.001

# %%
session = 'Mary-Anesthesia-20160912-02'
data_class = get_data_class(session, all_data_dir)
results_dir = f"/om/user/eisenaj/ChaoticConsciousness/results/{data_class}/{task_type}"
for window in windows:
    result_path = get_result_path(results_dir, session, window, window)
    for folder_name in os.listdir(result_path):
        folder_to_compile = os.path.join(result_path, folder_name)
        if os.path.isdir(os.path.join(result_path, folder_to_compile)):
            files = os.listdir(folder_to_compile)
            print(f"Now compiling {folder_to_compile}")
            if len(files[0].split('_')) == 5:
                temp_data = load(os.path.join(folder_to_compile, files[0]))
                if 'start_ind' in temp_data.keys():
                    compile_folder(folder_to_compile)
                else:
                    all_window_data = []
                    for file in tqdm(files):
                        window_start, window_end = float(file.split('_')[2]), float(file.split('_')[4])
                        window_data = load(os.path.join(folder_to_compile, file))
                        window_data['start_time'] = window_start
                        window_data['start_ind'] = int(window_start/dt)
                        window_data['end_time'] = window_end
                        window_data['end_ind'] = int(window_end/dt)
                        all_window_data.append(window_data) 

                    results_df = pd.DataFrame(all_window_data)

                    results_df = results_df.sort_values('start_ind')
                    results_df = results_df.reset_index(drop=True)

                    shutil.rmtree(folder_to_compile)

                    save(results_df, folder_to_compile)
            else:
                compile_folder(folder_to_compile)

# %%
session = 'MrJones-Anesthesia-20160301-01'
window = 9.5
stride = 9.5
bandpass_info = {'flag': True, 'low': 0.5, 'high': 100}

# %%
results_dir = "/om/user/eisenaj/ChaoticConsciousness/results/propofolPuffTone/VAR"

# %%
file_template = f"{os.path.basename(results_dir)}_{session}_window_{window}_stride_{stride}_" + "[a-zA-Z]{3}-"
regex = re.compile(file_template)

# %%
matching_files = []
for file in os.listdir(results_dir):
    if regex.match(file):
        matching_files.append(file)

# %%
get_result_path(results_dir, session, window, bandpass_info=None)
# Out:
# '/om/user/eisenaj/ChaoticConsciousness/results/propofolPuffTone/VAR/VAR_MrJones-Anesthesia-20160301-01_window_9.5_stride_9.5_Feb-23-2022_2121'
