# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np

# %%
def to_string(obj, f):
    if not isinstance(obj, h5py.Dataset):
        obj = f[obj]
    return ''.join([chr(int(i)) for i in obj[()]])

# %%
data_path = '../__data__/Mary-Anesthesia-20160809-01.mat'

# %%
f = h5py.File(data_path, 'r')
print(f.keys())
# Out:
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'ain', 'ainSchema', 'analogChnlInfo', 'electrodeInfo', 'eventSchema', 'fileInfo', 'lfp', 'lfpSchema', 'sessionInfo', 'spikeChnlInfo', 'spikeTimes', 'spikeTimesSchema', 'trialInfo', 'unitInfo']>

# %%
print(f['lfpSchema'].keys())
# to_string(f['lfpSchema']['timeUnits'], f)
for index in f['lfpSchema']['index'][:, 0]:
    print(f[index][()].shape)
    break
# Out:
# <KeysViewHDF5 ['dataDim', 'dataUnits', 'description', 'dims', 'history', 'index', 'indexUnits', 'mask', 'smpInterval', 'smpRate', 'timeUnits', 'userData']>
# (7085396, 1)

# %%
## SESSION INFO
sessionInfo = f['sessionInfo']
print(sessionInfo.keys())
print(''.join([chr(int(i)) for i in sessionInfo[sessionInfo['drug'][0][0]][()]]))
print(sessionInfo['drugDose'][()])
print(sessionInfo['drugDuration'][()])
print(sessionInfo['eyesClose'][()])
print(sessionInfo['eyesOpen'][()])
for array in sessionInfo['arrays']:
    print(to_string(array[0], f))
for area in sessionInfo['areas']:
    print(to_string(area[0], f))
print(sessionInfo)
# Out:
# <KeysViewHDF5 ['NSPs', 'Properties', 'areas', 'arrays', 'drug', 'drugDose', 'drugDuration', 'drugEnd', 'drugStart', 'drugTask', 'eyesClose', 'eyesOpen', 'hasDrug', 'hasWakeUpTest', 'numCorrect', 'numTrials', 'pctBadTrials', 'pctCorrect', 'session', 'subject', 'tasks']>
# propofol
# [[0.58]
#  [0.32]]
# [[30.]
#  [30.]]
# [[2254.01273333]
#  [2315.67226667]]
# [[5588.81433333]
#  [5618.68623333]]
# PFC
# FEF
# STG
# PPC
# vlPFC
# FEF
# CPB
# 7b

# %%
## SPIKE TIMES (in seconds)
spikeTimes = f['spikeTimes']
for unit in spikeTimes[:, 0]:
    print(f[unit][()])
    spike_times = f[unit][()]
    break
print(spikeTimes)
# Out:
# [[2.12466667e-01]
#  [5.03000000e-01]
#  [5.49900000e-01]
#  ...
#  [7.08538020e+03]
#  [7.08538333e+03]
#  [7.08538683e+03]]
# <HDF5 dataset "spikeTimes": shape (248, 1), type "|O">

# %% [markdown]
# - bins of size 50 ms, 100ms
# - non-overlapping stride

# %%
## ANALOG IN 
ain = f['ain']
# for unit in spikeTimes:
#     print(f[unit[0]][()])
#     break

# %%
airPuff = ain[7, :]
EMG = ain[10, :]

# %%
dt = 0.001
airPuff_sig = airPuff
plt.scatter(np.arange(len(airPuff_sig)), airPuff_sig, s=4)
# length = 1
# signal = EMG[int(3000/dt):int((3000 + length)/dt)]
# plt.scatter(np.arange(len(signal)), signal)
plt.show()

# %%
## ainSchema
ainSchema = f['ainSchema']
print(ainSchema.keys())
print(to_string(ainSchema['description'], f))
for index in ainSchema['index'][:, 0]:
    print(f[index])
for item in f[ainSchema['index'][1, 0]][:, 0]:
    print(to_string(item, f))
# Out:
# <KeysViewHDF5 ['dataDim', 'dataUnits', 'description', 'dims', 'history', 'index', 'indexUnits', 'mask', 'smpInterval', 'smpRate', 'timeUnits', 'userData']>
# Auxiliary AnalogIn (AIN) data
# <HDF5 dataset "wRc": shape (7085396, 1), type "<f8">
# <HDF5 dataset "xRc": shape (15, 1), type "|O">
# Mary-Anesthesia-20160809-01.reward
# Mary-Anesthesia-20160809-01.eyePosX
# Mary-Anesthesia-20160809-01.eyePosY
# Mary-Anesthesia-20160809-01.pupilSize
# Mary-Anesthesia-20160809-01.drugInfusion
# Mary-Anesthesia-20160809-01.bar
# Mary-Anesthesia-20160809-01.audio
# Mary-Anesthesia-20160809-01.airPuff
# Mary-Anesthesia-20160809-01.EEG
# Mary-Anesthesia-20160809-01.EMG
# Mary-Anesthesia-20160809-01.EEGbipolar
# Mary-Anesthesia-20160809-01.cereStim
# Mary-Anesthesia-20160809-01.SpO2
# Mary-Anesthesia-20160809-01.heartRate
# Mary-Anesthesia-20160809-01.cereStim_PPCSTG

# %%
## analogChnlInfo
analogChnlInfo = f['analogChnlInfo']
print(analogChnlInfo.keys())
analogChnlInfo['analogUnits']
analogChnlInfo['chnlLabel']
# Out:
# <KeysViewHDF5 ['Properties', 'analogRange', 'analogUnits', 'channel', 'chnlID', 'chnlLabel', 'd2aFactor', 'digitalRange', 'electrode', 'file', 'filterCutoff', 'isAIN', 'isLFP', 'numSamples', 'session', 'smpRate']>
# <HDF5 dataset "chnlLabel": shape (1, 268), type "|O">

# %%
## electrodeInfo
electrodeInfo = f['electrodeInfo']
print(electrodeInfo.keys())
print(electrodeInfo['hasLFP'])
# for file in electrodeInfo['file'][()][0]:
#     print(to_string(file, f))
# for area in electrodeInfo['area'][()][0]:
#     print(to_string(area, f))
print(electrodeInfo['gridLoc'])
for chnlID in electrodeInfo['chnlID'][()][0]:
    print(to_string(chnlID, f))
# Out:
# <KeysViewHDF5 ['NSP', 'Properties', 'area', 'array', 'channel', 'chnlID', 'electrode', 'file', 'gridLoc', 'hasLFP', 'hemisphere', 'numUnits', 'session']>
# <HDF5 dataset "hasLFP": shape (1, 253), type "|u1">
# <HDF5 dataset "gridLoc": shape (2, 253), type "<f8">
# Mary-Anesthesia-20160809-01.001
# Mary-Anesthesia-20160809-01.002
# Mary-Anesthesia-20160809-01.003
# Mary-Anesthesia-20160809-01.004
# Mary-Anesthesia-20160809-01.005
# Mary-Anesthesia-20160809-01.006
# Mary-Anesthesia-20160809-01.007
# Mary-Anesthesia-20160809-01.008
# Mary-Anesthesia-20160809-01.009
# Mary-Anesthesia-20160809-01.010
# Mary-Anesthesia-20160809-01.011
# Mary-Anesthesia-20160809-01.012
# Mary-Anesthesia-20160809-01.013
# Mary-Anesthesia-20160809-01.014
# Mary-Anesthesia-20160809-01.015
# Mary-Anesthesia-20160809-01.016
# Mary-Anesthesia-20160809-01.017
# Mary-Anesthesia-20160809-01.018
# Mary-Anesthesia-20160809-01.019
# Mary-Anesthesia-20160809-01.020
# Mary-Anesthesia-20160809-01.021
# Mary-Anesthesia-20160809-01.022
# Mary-Anesthesia-20160809-01.023
# Mary-Anesthesia-20160809-01.024
# Mary-Anesthesia-20160809-01.025
# Mary-Anesthesia-20160809-01.026
# Mary-Anesthesia-20160809-01.027
# Mary-Anesthesia-20160809-01.028
# Mary-Anesthesia-20160809-01.029
# Mary-Anesthesia-20160809-01.030
# Mary-Anesthesia-20160809-01.031
# Mary-Anesthesia-20160809-01.032
# Mary-Anesthesia-20160809-01.033
# Mary-Anesthesia-20160809-01.034
# Mary-Anesthesia-20160809-01.035
# Mary-Anesthesia-20160809-01.036
# Mary-Anesthesia-20160809-01.037
# Mary-Anesthesia-20160809-01.038
# Mary-Anesthesia-20160809-01.039
# Mary-Anesthesia-20160809-01.040
# Mary-Anesthesia-20160809-01.041
# Mary-Anesthesia-20160809-01.042
# Mary-Anesthesia-20160809-01.043
# Mary-Anesthesia-20160809-01.044
# Mary-Anesthesia-20160809-01.045
# Mary-Anesthesia-20160809-01.046
# Mary-Anesthesia-20160809-01.047
# Mary-Anesthesia-20160809-01.048
# Mary-Anesthesia-20160809-01.049
# Mary-Anesthesia-20160809-01.050
# Mary-Anesthesia-20160809-01.051
# Mary-Anesthesia-20160809-01.052
# Mary-Anesthesia-20160809-01.053
# Mary-Anesthesia-20160809-01.054
# Mary-Anesthesia-20160809-01.055
# Mary-Anesthesia-20160809-01.056
# Mary-Anesthesia-20160809-01.057
# Mary-Anesthesia-20160809-01.058
# Mary-Anesthesia-20160809-01.059
# Mary-Anesthesia-20160809-01.060
# Mary-Anesthesia-20160809-01.061
# Mary-Anesthesia-20160809-01.062
# Mary-Anesthesia-20160809-01.063
# Mary-Anesthesia-20160809-01.064
# Mary-Anesthesia-20160809-01.065
# Mary-Anesthesia-20160809-01.066
# Mary-Anesthesia-20160809-01.067
# Mary-Anesthesia-20160809-01.068
# Mary-Anesthesia-20160809-01.069
# Mary-Anesthesia-20160809-01.070
# Mary-Anesthesia-20160809-01.071
# Mary-Anesthesia-20160809-01.072
# Mary-Anesthesia-20160809-01.073
# Mary-Anesthesia-20160809-01.074
# Mary-Anesthesia-20160809-01.075
# Mary-Anesthesia-20160809-01.076
# Mary-Anesthesia-20160809-01.077
# Mary-Anesthesia-20160809-01.078
# Mary-Anesthesia-20160809-01.079
# Mary-Anesthesia-20160809-01.080
# Mary-Anesthesia-20160809-01.081
# Mary-Anesthesia-20160809-01.082
# Mary-Anesthesia-20160809-01.084
# Mary-Anesthesia-20160809-01.085
# Mary-Anesthesia-20160809-01.087
# Mary-Anesthesia-20160809-01.088
# Mary-Anesthesia-20160809-01.089
# Mary-Anesthesia-20160809-01.091
# Mary-Anesthesia-20160809-01.092
# Mary-Anesthesia-20160809-01.093
# Mary-Anesthesia-20160809-01.094
# Mary-Anesthesia-20160809-01.095
# Mary-Anesthesia-20160809-01.096
# Mary-Anesthesia-20160809-01.097
# Mary-Anesthesia-20160809-01.098
# Mary-Anesthesia-20160809-01.099
# Mary-Anesthesia-20160809-01.100
# Mary-Anesthesia-20160809-01.101
# Mary-Anesthesia-20160809-01.102
# Mary-Anesthesia-20160809-01.103
# Mary-Anesthesia-20160809-01.104
# Mary-Anesthesia-20160809-01.105
# Mary-Anesthesia-20160809-01.106
# Mary-Anesthesia-20160809-01.107
# Mary-Anesthesia-20160809-01.108
# Mary-Anesthesia-20160809-01.109
# Mary-Anesthesia-20160809-01.110
# Mary-Anesthesia-20160809-01.111
# Mary-Anesthesia-20160809-01.112
# Mary-Anesthesia-20160809-01.113
# Mary-Anesthesia-20160809-01.114
# Mary-Anesthesia-20160809-01.115
# Mary-Anesthesia-20160809-01.116
# Mary-Anesthesia-20160809-01.117
# Mary-Anesthesia-20160809-01.118
# Mary-Anesthesia-20160809-01.119
# Mary-Anesthesia-20160809-01.120
# Mary-Anesthesia-20160809-01.121
# Mary-Anesthesia-20160809-01.122
# Mary-Anesthesia-20160809-01.123
# Mary-Anesthesia-20160809-01.124
# Mary-Anesthesia-20160809-01.125
# Mary-Anesthesia-20160809-01.126
# Mary-Anesthesia-20160809-01.127
# Mary-Anesthesia-20160809-01.128
# Mary-Anesthesia-20160809-01.129
# Mary-Anesthesia-20160809-01.130
# Mary-Anesthesia-20160809-01.131
# Mary-Anesthesia-20160809-01.132
# Mary-Anesthesia-20160809-01.133
# Mary-Anesthesia-20160809-01.134
# Mary-Anesthesia-20160809-01.135
# Mary-Anesthesia-20160809-01.136
# Mary-Anesthesia-20160809-01.137
# Mary-Anesthesia-20160809-01.138
# Mary-Anesthesia-20160809-01.139
# Mary-Anesthesia-20160809-01.140
# Mary-Anesthesia-20160809-01.141
# Mary-Anesthesia-20160809-01.142
# Mary-Anesthesia-20160809-01.143
# Mary-Anesthesia-20160809-01.144
# Mary-Anesthesia-20160809-01.145
# Mary-Anesthesia-20160809-01.146
# Mary-Anesthesia-20160809-01.147
# Mary-Anesthesia-20160809-01.148
# Mary-Anesthesia-20160809-01.149
# Mary-Anesthesia-20160809-01.150
# Mary-Anesthesia-20160809-01.151
# Mary-Anesthesia-20160809-01.152
# Mary-Anesthesia-20160809-01.153
# Mary-Anesthesia-20160809-01.154
# Mary-Anesthesia-20160809-01.155
# Mary-Anesthesia-20160809-01.156
# Mary-Anesthesia-20160809-01.157
# Mary-Anesthesia-20160809-01.158
# Mary-Anesthesia-20160809-01.159
# Mary-Anesthesia-20160809-01.160
# Mary-Anesthesia-20160809-01.161
# Mary-Anesthesia-20160809-01.162
# Mary-Anesthesia-20160809-01.163
# Mary-Anesthesia-20160809-01.164
# Mary-Anesthesia-20160809-01.165
# Mary-Anesthesia-20160809-01.166
# Mary-Anesthesia-20160809-01.167
# Mary-Anesthesia-20160809-01.168
# Mary-Anesthesia-20160809-01.169
# Mary-Anesthesia-20160809-01.170
# Mary-Anesthesia-20160809-01.171
# Mary-Anesthesia-20160809-01.172
# Mary-Anesthesia-20160809-01.173
# Mary-Anesthesia-20160809-01.174
# Mary-Anesthesia-20160809-01.175
# Mary-Anesthesia-20160809-01.176
# Mary-Anesthesia-20160809-01.177
# Mary-Anesthesia-20160809-01.178
# Mary-Anesthesia-20160809-01.179
# Mary-Anesthesia-20160809-01.180
# Mary-Anesthesia-20160809-01.181
# Mary-Anesthesia-20160809-01.182
# Mary-Anesthesia-20160809-01.183
# Mary-Anesthesia-20160809-01.184
# Mary-Anesthesia-20160809-01.185
# Mary-Anesthesia-20160809-01.186
# Mary-Anesthesia-20160809-01.187
# Mary-Anesthesia-20160809-01.188
# Mary-Anesthesia-20160809-01.189
# Mary-Anesthesia-20160809-01.190
# Mary-Anesthesia-20160809-01.191
# Mary-Anesthesia-20160809-01.192
# Mary-Anesthesia-20160809-01.193
# Mary-Anesthesia-20160809-01.194
# Mary-Anesthesia-20160809-01.195
# Mary-Anesthesia-20160809-01.196
# Mary-Anesthesia-20160809-01.197
# Mary-Anesthesia-20160809-01.198
# Mary-Anesthesia-20160809-01.199
# Mary-Anesthesia-20160809-01.200
# Mary-Anesthesia-20160809-01.201
# Mary-Anesthesia-20160809-01.202
# Mary-Anesthesia-20160809-01.203
# Mary-Anesthesia-20160809-01.204
# Mary-Anesthesia-20160809-01.205
# Mary-Anesthesia-20160809-01.206
# Mary-Anesthesia-20160809-01.207
# Mary-Anesthesia-20160809-01.208
# Mary-Anesthesia-20160809-01.209
# Mary-Anesthesia-20160809-01.210
# Mary-Anesthesia-20160809-01.211
# Mary-Anesthesia-20160809-01.212
# Mary-Anesthesia-20160809-01.213
# Mary-Anesthesia-20160809-01.214
# Mary-Anesthesia-20160809-01.215
# Mary-Anesthesia-20160809-01.216
# Mary-Anesthesia-20160809-01.217
# Mary-Anesthesia-20160809-01.218
# Mary-Anesthesia-20160809-01.219
# Mary-Anesthesia-20160809-01.220
# Mary-Anesthesia-20160809-01.221
# Mary-Anesthesia-20160809-01.222
# Mary-Anesthesia-20160809-01.223
# Mary-Anesthesia-20160809-01.224
# Mary-Anesthesia-20160809-01.225
# Mary-Anesthesia-20160809-01.226
# Mary-Anesthesia-20160809-01.227
# Mary-Anesthesia-20160809-01.228
# Mary-Anesthesia-20160809-01.229
# Mary-Anesthesia-20160809-01.230
# Mary-Anesthesia-20160809-01.231
# Mary-Anesthesia-20160809-01.232
# Mary-Anesthesia-20160809-01.233
# Mary-Anesthesia-20160809-01.234
# Mary-Anesthesia-20160809-01.235
# Mary-Anesthesia-20160809-01.236
# Mary-Anesthesia-20160809-01.237
# Mary-Anesthesia-20160809-01.238
# Mary-Anesthesia-20160809-01.239
# Mary-Anesthesia-20160809-01.240
# Mary-Anesthesia-20160809-01.241
# Mary-Anesthesia-20160809-01.242
# Mary-Anesthesia-20160809-01.243
# Mary-Anesthesia-20160809-01.244
# Mary-Anesthesia-20160809-01.245
# Mary-Anesthesia-20160809-01.246
# Mary-Anesthesia-20160809-01.247
# Mary-Anesthesia-20160809-01.248
# Mary-Anesthesia-20160809-01.249
# Mary-Anesthesia-20160809-01.250
# Mary-Anesthesia-20160809-01.251
# Mary-Anesthesia-20160809-01.252
# Mary-Anesthesia-20160809-01.253
# Mary-Anesthesia-20160809-01.254
# Mary-Anesthesia-20160809-01.255
# Mary-Anesthesia-20160809-01.256

# %%
lfp = f['lfp']
lfp.shape
# Out:
# (253, 7085396)

# %%
## unitInfo
unitInfo = f['unitInfo']
print(unitInfo.keys())
# for file in electrodeInfo['file'][()][0]:
#     print(to_string(file, f))
print(unitInfo['area'])
for area in unitInfo['area'][()][0]:
    print(to_string(area, f))
# Out:
# <KeysViewHDF5 ['NSP', 'Properties', 'area', 'array', 'channel', 'chnlID', 'electrode', 'file', 'gridLoc', 'hemisphere', 'numSpikes', 'session', 'unit', 'unitID']>
# <HDF5 dataset "area": shape (1, 248), type "|O">
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# vlPFC
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# FEF
# CPB
# CPB
# CPB
# CPB
# CPB
# CPB
# CPB
# CPB
# CPB
# CPB
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
# 7b
